# %% [markdown]
# # DAX Perf Optimizer
#
# Opens the interactive DAX performance optimizer from **semantic-link-labs**, which
# profiles a semantic model and suggests changes.
#
# This notebook pins a **specific build of semantic-link-labs**, installed from a wheel
# published alongside the workshop labs rather than from PyPI, because `dax_perf_optimizer`
# is newer than the released package. The lab notebooks are unaffected and still install
# `semantic-link-labs` normally.
#
# Run as a **Python** notebook, not PySpark. There is no Spark session to wait for.

# %%
# Alone, and first. In Fabric %pip restarts the Python interpreter, so anything
# defined before it is lost. Imports therefore live in the next cell.
# %pip install -q "https://raw.githubusercontent.com/dax-tips/SuccessfulSemanticModelling/main/labs/notebooks/semantic_link_labs-0.17.4-py3-none-any.whl"

# %%
from sempy_labs.semantic_model._dax_perf import dax_perf_optimizer

dax_perf_optimizer()
